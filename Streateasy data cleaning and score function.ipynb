# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

#define our brooklyn dataframe and main statistics
brooklyn = pd.read_csv('brooklyn.csv')
brooklyn['one_bedroom'] = brooklyn.bedrooms.apply(lambda x: 'one_bedroom' if x == 1 else None)
average_brooklyn_rent = np.mean(brooklyn['rent'])
brooklyn['rent price vs avg'] = brooklyn.rent.apply(lambda x: 'Above avg rent' if x > 3327 else 'below avg rent')
brooklyn_rent_sd = np.std(brooklyn['rent'])
brooklyn_rent_median = np.median(brooklyn['rent'])
#printing the main statistics of the brooklyn dataframe
try: 
    print('The average price of rent in Brooklyn is $' + str(round(average_brooklyn_rent, 2)))
except NameError: 
    print('The average price of rent in Brooklyn is not defined')
    
try: 
    print('The median price of rent in Brooklyn is $' + str(round(brooklyn_rent_median, 2)))
except NameError: 
    print('The median price of rent in Brooklyn is not defined')
    
try: 
    print('The standard deviation of rent prices in Brooklyn is $' +  str(round(brooklyn_rent_sd, 2)))
except NameError: 
    print('The standard deviation of rent prices in Brooklyn is not defined')
    
#defining our score functionn that gives each attribute a certain value out of 100
def score(row): 
    score = 0
    if row['has_elevator']  :
        score = score+ 40
    if row['has_dishwasher'] :
        score = score + 20
    if row['has_washer_dryer']: 
        score = score + 30
    if row['has_doorman']:
        score = score + 10
    return score
   
brooklyn['score'] = brooklyn.apply(score, axis = 1)

#sorting the rent of a one bedroom or studio apartment along with our score column
print(brooklyn.sort_values('score',ascending=0)[['bedrooms','bathrooms','score', 'rent','neighborhood', 'rent price vs avg']].head(40))

#print the average rent prices of 1 bedroom or studio apartments by neighborhood in brooklyn    
print('The average rent of a studio or one bedroom apartment by neighborhood:')
brooklyn_onebr = brooklyn[brooklyn['bedrooms']<=1]
neighborhood_means_onebr = brooklyn_onebr[['neighborhood', 'rent']].groupby(['neighborhood']).mean()
mean_rent_onebr_by_neighborhood = neighborhood_means_onebr.sort_values(['rent']).reset_index()
print(mean_rent_onebr_by_neighborhood)
# Out:
# The average price of rent in Brooklyn is $3327.4
# The median price of rent in Brooklyn is $3000.0
# The standard deviation of rent prices in Brooklyn is $1601.6
#       bedrooms  bathrooms  score   rent        neighborhood rent price vs avg
# 1012       3.0          2    100  18000               DUMBO    Above avg rent
# 645        0.0          1    100   2215   Downtown Brooklyn    below avg rent
# 78         2.0          2    100   6300    Brooklyn Heights    Above avg rent
# 420        2.0          2    100   5995        Williamsburg    Above avg rent
# 417        1.0          1    100   3000        Williamsburg    below avg rent
# 199        0.0          1    100   2400   Downtown Brooklyn    below avg rent
# 807        1.0          1    100   1500       Ocean Parkway    below avg rent
# 32         1.0          2    100   4000        Williamsburg    Above avg rent
# 789        1.0          1    100   3500  Bedford-Stuyvesant    Above avg rent
# 266        1.0          1    100   2700     Carroll Gardens    below avg rent
# 388        3.0          1    100   3795         Cobble Hill    Above avg rent
# 288        1.0          1    100   2550          Park Slope    below avg rent
# 295        2.0          1    100   3600   Downtown Brooklyn    Above avg rent
# 716        2.0          4    100   9000        Williamsburg    Above avg rent
# 882        1.0          1    100   3200         Fort Greene    below avg rent
# 300        2.0          2    100   6600    Brooklyn Heights    Above avg rent
# 57         1.0          1    100   3100   Downtown Brooklyn    below avg rent
# 658        1.0          1    100   3450    Brooklyn Heights    Above avg rent
# 665        2.0          1    100   4075               DUMBO    Above avg rent
# 595        2.0          2    100   3000  Bedford-Stuyvesant    below avg rent
# 549        1.0          1    100   2350               DUMBO    below avg rent
# 505        4.0          1    100   3250  Bedford-Stuyvesant    below avg rent
# 1009       3.0          2    100   3750       Crown Heights    Above avg rent
# 605        1.0          1    100   2550        Clinton Hill    below avg rent
# 530        1.0          1    100   1750       Ocean Parkway    below avg rent
# 572        1.0          1    100   3100         Fort Greene    below avg rent
# 125        0.0          1    100   2500   Downtown Brooklyn    below avg rent
# 668        1.0          1     90   3100         Fort Greene    below avg rent
# 574        0.0          1     90   2200   Downtown Brooklyn    below avg rent
# 61         2.0          2     90   4079        Clinton Hill    Above avg rent
# 644        2.0          1     90   3400        Williamsburg    Above avg rent
# 763        2.0          1     90   3675         Boerum Hill    Above avg rent
# 172        1.0          1     90   3900        Williamsburg    Above avg rent
# 90         0.0          1     90   3600   Downtown Brooklyn    Above avg rent
# 970        1.0          1     80   3195               DUMBO    below avg rent
# 529        1.0          1     80   1900        Williamsburg    below avg rent
# 555        1.0          1     80   1575        Coney Island    below avg rent
# 399        1.0          1     80   2800             Gowanus    below avg rent
# 636        2.0          2     80   9495               DUMBO    Above avg rent
# 82         0.0          1     80   2900               DUMBO    below avg rent
# The average rent of a studio or one bedroom apartment by neighborhood:
#                        neighborhood         rent
# 0                     East Flatbush  1450.000000
# 1                       Brownsville  1466.666667
# 2                         Gravesend  1561.666667
# 3                       Sunset Park  1562.500000
# 4                    Sheepshead Bay  1575.000000
# 5                     Ocean Parkway  1575.000000
# 6                        Kensington  1645.000000
# 7                         Bay Ridge  1703.125000
# 8                   Windsor Terrace  1708.333333
# 9                    Brighton Beach  1730.000000
# 10                     Coney Island  1781.500000
# 11                         Flatbush  1868.222222
# 12        Prospect Lefferts Gardens  1890.000000
# 13                    Crown Heights  1963.235294
# 14                      Ditmas Park  2025.000000
# 15                        Greenwood  2061.000000
# 16              Prospect Park South  2233.000000
# 17                         Bushwick  2264.285714
# 18                       Park Slope  2314.473684
# 19                  Carroll Gardens  2352.083333
# 20               Bedford-Stuyvesant  2438.076923
# 21                      Cobble Hill  2485.000000
# 22                      Boerum Hill  2518.000000
# 23                       Greenpoint  2576.812500
# 24                          Gowanus  2600.000000
# 25                     Clinton Hill  2611.000000
# 26                      Fort Greene  2844.375000
# 27  Columbia St Waterfront District  2950.000000
# 28                Downtown Brooklyn  2956.938462
# 29                 Prospect Heights  3000.000000
# 30                     Williamsburg  3029.696296
# 31                 Brooklyn Heights  3397.363636
# 32                         Red Hook  3400.000000
# 33                            DUMBO  3693.266667

# %%
#define our manhattan dataframe and main statistics
manhattan = pd.read_csv('manhattan.csv')
manhattan['one_bedroom'] = manhattan.bedrooms.apply(lambda x: 'one_bedroom' if x == 1 else None)
average_manhattan_rent = np.mean(manhattan['rent'])
manhattan['rent price vs avg'] = manhattan.rent.apply(lambda x: 'Above avg rent' if x > 5138 else 'below avg rent')
manhattan_rent_sd = np.std(manhattan['rent'])
manhattan_rent_median = np.median(manhattan['rent'])
#printing the main statistics of the manhattan dataframe
try: 
    print('The average price of rent in Manhattan is $' + str(round(average_manhattan_rent, 2)))
except NameError: 
    print('The average price of rent in Manhattan is not defined')
    
try: 
    print('The median price of rent in Manhattan is $' + str(round(manhattan_rent_median, 2)))
except NameError: 
    print('The median price of rent in Manhattan is not defined')
    
try: 
    print('The standard deviation of rent prices in Manhattan is $' +  str(round(manhattan_rent_sd, 2)))
except NameError: 
    print('The standard deviation of rent prices in Manhattan is not defined')
    
#defining our score functionn that gives each attribute a certain value out of 100
def score(row): 
    score = 0
    if row['has_elevator']  :
        score = score+ 40
    if row['has_dishwasher'] :
        score = score + 20
    if row['has_washer_dryer']: 
        score = score + 30
    if row['has_doorman']:
        score = score + 10
    return score
   
manhattan['score'] = manhattan.apply(score, axis = 1)


#print the rent prices of 1 bedroom or studio apartments by neighborhood in manhattan    

print('The average rent of a studio or one bedroom apartment by neighborhood:')
manhattan_onebr = manhattan[manhattan['bedrooms']<=1]
neighborhood_means_onebr = manhattan_onebr[['neighborhood', 'rent']].groupby(['neighborhood']).mean()
print(neighborhood_means_onebr.sort_values(['rent']))

#sorting the average rent of a one bedroom or studio apartment along with our score column
print(manhattan.sort_values('score',ascending=0)[['bedrooms','bathrooms','score', 'rent','neighborhood', 'rent price vs avg']].head(40))
# Out:
# The average price of rent in Manhattan is $5138.94
# The median price of rent in Manhattan is $4000.0
# The standard deviation of rent prices in Manhattan is $3162.38
# The average rent of a studio or one bedroom apartment by neighborhood:
#                             rent
# neighborhood
# Manhattanville       1395.000000
# Inwood               1807.142857
# Washington Heights   1827.958333
# Hamilton Heights     1861.000000
# Central Harlem       2034.054054
# Little Italy         2248.000000
# East Harlem          2373.727273
# Chinatown            2624.166667
# Roosevelt Island     2825.000000
# Long Island City     2957.000000
# Morningside Heights  3156.666667
# Lower East Side      3164.000000
# Upper East Side      3345.700787
# Midtown West         3394.881818
# Midtown East         3427.135417
# Upper West Side      3451.125000
# Financial District   3535.631313
# Battery Park City    3592.959184
# East Village         3630.428571
# Gramercy Park        3796.738095
# Midtown South        3825.015385
# Stuyvesant Town/PCV  3847.000000
# Greenwich Village    4075.081633
# Midtown              4494.277108
# Flatiron             4539.102273
# Chelsea              4560.841667
# West Village         4652.000000
# Central Park South   5054.000000
# Tribeca              5149.716667
# Nolita               5345.000000
# Soho                 5466.478261
#       bedrooms  bathrooms  score   rent        neighborhood rent price vs avg
# 1769       1.0          1    100   3800        East Village    below avg rent
# 1665       1.0          1    100   3600        Midtown West    below avg rent
# 1635       2.0          3    100  11000     Upper East Side    Above avg rent
# 1598       2.0          2    100   5500        Midtown East    Above avg rent
# 1569       0.0          1    100   2695   Greenwich Village    below avg rent
# 1566       0.0          1    100   2600     Upper East Side    below avg rent
# 1547       2.0          1    100   2995        Midtown West    below avg rent
# 1540       1.0          1    100   3150        Midtown East    below avg rent
# 1535       2.0          2    100   4999     Upper East Side    below avg rent
# 1521       2.0          1    100   6500   Greenwich Village    Above avg rent
# 1510       2.0          2    100   7550   Battery Park City    Above avg rent
# 1509       1.0          1    100   1795              Inwood    below avg rent
# 1495       2.0          2    100  10000     Upper East Side    Above avg rent
# 1485       1.0          1    100   4100   Battery Park City    below avg rent
# 1465       0.0          1    100   2390        Midtown East    below avg rent
# 1457       2.0          1    100   2995        Midtown East    below avg rent
# 1456       1.0          1    100   4915        Midtown East    below avg rent
# 1449       2.0          2    100   6200     Upper East Side    Above avg rent
# 225        3.0          2    100   6400             Chelsea    Above avg rent
# 1368       0.0          2    100   2745     Upper West Side    below avg rent
# 1365       0.0          1    100   3940             Chelsea    below avg rent
# 1346       0.0          1    100   2600   Battery Park City    below avg rent
# 234        2.0          2    100   6800       Midtown South    Above avg rent
# 1344       1.0          1    100   3553        Midtown West    below avg rent
# 1334       0.0          1    100   2500             Tribeca    below avg rent
# 1324       1.0          1    100   4116            Flatiron    below avg rent
# 1296       1.0          1    100   5400        East Village    Above avg rent
# 1279       1.0          1    100   4370   Battery Park City    below avg rent
# 1265       0.0          1    100   3195     Upper East Side    below avg rent
# 1257       1.0          2    100  10200             Tribeca    Above avg rent
# 247        1.0          1    100   4950  Financial District    below avg rent
# 1647       1.0          1    100   3500     Upper West Side    below avg rent
# 1670       0.0          1    100   2880             Midtown    below avg rent
# 2245       1.0          1    100   3410             Chelsea    below avg rent
# 1693       1.0          1    100   3700     Upper West Side    below avg rent
# 2170       2.0          1    100   5795   Battery Park City    Above avg rent
# 2169       1.0          1    100   3650     Upper West Side    below avg rent
# 2168       0.0          1    100   2750   Greenwich Village    below avg rent
# 2157       2.0          2    100   7750   Battery Park City    Above avg rent
# 2143       1.0          1    100   3750     Upper East Side    below avg rent

# %%
#define our queens dataframe and main statistics
queens = pd.read_csv('queens.csv')
queens['one_bedroom'] = queens.bedrooms.apply(lambda x: 'one_bedroom' if x == 1 else None)
average_queens_rent = np.mean(queens['rent'])
queens['rent price vs avg'] = queens.rent.apply(lambda x: 'Above avg rent' if x > 2516 else 'below avg rent')
queens_rent_sd = np.std(queens['rent'])
queens_rent_median = np.median(queens['rent'])
#printing the main statistics of the queens dataframe
try: 
    print('The average price of rent in Queens is $' + str(round(average_queens_rent, 2)))
except NameError: 
    print('The average price of rent in Queens is not defined')
    
try: 
    print('The median price of rent in Queens is $' + str(round(queens_rent_median, 2)))
except NameError: 
    print('The median price of rent in Queens is not defined')
    
try: 
    print('The standard deviation of rent prices in Queens is $' +  str(round(queens_rent_sd, 2)))
except NameError: 
    print('The standard deviation of rent prices in Queens is not defined')
    
#defining our score functionn that gives each attribute a certain value out of 100
def score(row): 
    score = 0
    if row['has_elevator']  :
        score = score+ 40
    if row['has_dishwasher'] :
        score = score + 20
    if row['has_washer_dryer']: 
        score = score + 30
    if row['has_doorman']:
        score = score + 10
    return score
   
queens['score'] = queens.apply(score, axis = 1)

#sorting the rent of a one bedroom or studio apartment along with our score column
print(queens.sort_values('score',ascending=0)[['bedrooms','bathrooms','score', 'rent','neighborhood', 'rent price vs avg']].head(40))

#print the average rent prices of 1 bedroom or studio apartments by neighborhood in queens    
print('The average rent of a one bedroom or studio apartment by neighborhood in Queens')
queens_onebr = queens[queens['bedrooms']<=1]
neighborhood_means_onebr = queens_onebr[['neighborhood', 'rent']].groupby(['neighborhood']).mean()
print(neighborhood_means_onebr.sort_values(['rent']))
# Out:
# The average price of rent in Queens is $2516.15
# The median price of rent in Queens is $2350.0
# The standard deviation of rent prices in Queens is $853.66
#      bedrooms  bathrooms  score  rent      neighborhood rent price vs avg
# 286       1.0          1    100  2100         Rego Park    below avg rent
# 318       2.0          1    100  2250          Flushing    below avg rent
# 262       0.0          1    100  1575       Kew Gardens    below avg rent
# 306       1.0          1    100  2400           Astoria    below avg rent
# 24        1.0          1    100  3450  Long Island City    Above avg rent
# 212       1.0          1    100  3400  Long Island City    Above avg rent
# 207       1.0          1    100  1925         Sunnyside    below avg rent
# 327       0.0          1    100  2650  Long Island City    Above avg rent
# 227       1.0          1     90  1900      Forest Hills    below avg rent
# 440       2.0          2     90  4850  Long Island City    Above avg rent
# 141       1.0          1     90  2650      Forest Hills    Above avg rent
# 85        2.0          2     80  5700  Long Island City    Above avg rent
# 333       1.0          1     80  3325  Long Island City    Above avg rent
# 345       1.0          1     80  2595      Forest Hills    Above avg rent
# 46        1.0          1     80  2500           Astoria    below avg rent
# 43        1.0          1     80  3450  Long Island City    Above avg rent
# 276       2.0          2     70  2450       Kew Gardens    below avg rent
# 60        2.0          2     70  3795  Long Island City    Above avg rent
# 159       0.0          1     70  1475      Forest Hills    below avg rent
# 417       2.0          2     70  4350  Long Island City    Above avg rent
# 142       1.0          1     70  1750      Forest Hills    below avg rent
# 127       1.0          1     70  1950       Kew Gardens    below avg rent
# 250       2.0          1     60  3600           Astoria    Above avg rent
# 299       1.0          1     50  1900           Astoria    below avg rent
# 86        2.0          2     50  4100  Long Island City    Above avg rent
# 416       1.0          1     50  2050           Astoria    below avg rent
# 64        1.0          1     50  2995  Long Island City    Above avg rent
# 99        1.0          1     50  3500  Long Island City    Above avg rent
# 29        1.0          1     50  2000       Kew Gardens    below avg rent
# 392       2.0          2     50  3950  Long Island City    Above avg rent
# 310       2.0          2     50  4000  Long Island City    Above avg rent
# 239       3.0          2     50  3750           Astoria    Above avg rent
# 160       1.0          1     50  3300  Long Island City    Above avg rent
# 7         1.0          1     50  3100  Long Island City    Above avg rent
# 234       1.0          1     50  2400           Astoria    below avg rent
# 430       1.0          1     50  2350           Astoria    below avg rent
# 103       2.0          2     50  2795       Kew Gardens    Above avg rent
# 325       1.0          1     40  3300  Long Island City    Above avg rent
# 216       1.0          1     40  3150  Long Island City    Above avg rent
# 435       1.0          1     40  1600         Sunnyside    below avg rent
# The average rent of a one bedroom or studio apartment by neighborhood in Queens
#                           rent
# neighborhood
# Jamaica Estates    1424.833333
# Richmond Hill      1450.000000
# Queens Village     1487.500000
# Briarwood          1524.571429
# Woodside           1586.666667
# Jamaica Hills      1625.000000
# Woodhaven          1650.000000
# Rockaway All       1650.000000
# Ridgewood          1700.000000
# Jackson Heights    1705.000000
# Elmhurst           1707.500000
# Sunnyside          1816.666667
# Kew Gardens        1825.000000
# Rego Park          1862.413793
# Flushing           1876.666667
# North Corona       2000.000000
# Corona             2000.000000
# Kew Gardens Hills  2047.000000
# Forest Hills       2103.166667
# Astoria            2391.217949
# Long Island City   2951.823529
